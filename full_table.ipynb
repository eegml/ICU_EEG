# %%
import pandas as pd
import numpy as np
import yaml
import json

# %% [markdown]
# Early notes: There are some subjects in the repository which were not ultimately used in the published form of this project (in particular, anything with 'IIC' in it - these were interictal - ictal continuum patients which we did not want to use in training the model), as well as a few others which clinicians on our team judged to have insufficient data quality. We also had to re-upload files recently under new IDs on ieeg.org for deidentification purposes which may have made some of the annotation files fail.
#
# It looks like the annotations are labeled in seconds.
# I'm not sure what the ii_start and ii_start are for.

# %%
pt_df = pd.read_csv('patient_table.csv')

# %%
pt_df
# Out:
#             portal_id  annotation_no  sz_presence diagnosis  Age Sex  \
# 0   ICUDataRedux_0060              1            1       AMS   87   F
# 1   ICUDataRedux_0061              2            1        SZ   60   F
# 2   ICUDataRedux_0062              3            1        SZ   64   M
# 3   ICUDataRedux_0063              4            1        SZ   59   F
# 4   ICUDataRedux_0064              5            1        SZ   45   F
# ..                ...            ...          ...       ...  ...  ..
# 92  ICUDataRedux_0035            130            2       AMS   30   M
# 93  ICUDataRedux_0043            131            2        SZ   38   F
# 94  ICUDataRedux_0044            132            2    Anoxic   64   M
# 95  ICUDataRedux_0047            133            2       AMS   58   F
# 96  ICUDataRedux_0048            134            2    Sepsis   60   F
#
#     Test_set  sz_num  mean_sz_len  record_len  num_artifact
# 0          0       2      100.500       30000             3
# 1          0      49      110.180       31855           266
# 2          0      22       22.136       23500             1
# 3          0       5       20.800       30170           198
# 4          0      39       74.179       14995             2
# ..       ...     ...          ...         ...           ...
# 92         1       0          NaN       10000             0
# 93         1       0          NaN       10000             0
# 94         1       0          NaN       10000             0
# 95         1       0          NaN       10000            46
# 96         1       0          NaN       10000             0
#
# [97 rows x 11 columns]

# %%
pt_df = pt_df.sort_values(by='annotation_no')
pt_df.to_csv('patient_table_sorted.csv',index=False)

# %%
annotations = yaml.safe_load(open('Data/annotations.yaml'))

# %%
ptdf2 = pt_df.set_index(['annotation_no'])
ptdatadict = ptdf2.to_dict(orient='index')

# %%
len(ptdatadict)
ptdatadict
# Out:
# {1: {'portal_id': 'ICUDataRedux_0060',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'Age': 87,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 2,
#   'mean_sz_len': 100.5,
#   'record_len': 30000,
#   'num_artifact': 3},
#  2: {'portal_id': 'ICUDataRedux_0061',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 60,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 49,
#   'mean_sz_len': 110.18,
#   'record_len': 31855,
#   'num_artifact': 266},
#  3: {'portal_id': 'ICUDataRedux_0062',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 64,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 22,
#   'mean_sz_len': 22.136,
#   'record_len': 23500,
#   'num_artifact': 1},
#  4: {'portal_id': 'ICUDataRedux_0063',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 59,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 5,
#   'mean_sz_len': 20.8,
#   'record_len': 30170,
#   'num_artifact': 198},
#  5: {'portal_id': 'ICUDataRedux_0064',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 45,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 39,
#   'mean_sz_len': 74.179,
#   'record_len': 14995,
#   'num_artifact': 2},
#  6: {'portal_id': 'ICUDataRedux_0065',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 47,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 4,
#   'mean_sz_len': 139.0,
#   'record_len': 7000,
#   'num_artifact': 71},
#  7: {'portal_id': 'ICUDataRedux_0066',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 43,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 5,
#   'mean_sz_len': 224.2,
#   'record_len': 37000,
#   'num_artifact': 30},
#  8: {'portal_id': 'ICUDataRedux_0067',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 70,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 4,
#   'mean_sz_len': 139.0,
#   'record_len': 32975,
#   'num_artifact': 15},
#  9: {'portal_id': 'ICUDataRedux_0068',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 77,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 4,
#   'mean_sz_len': 29.75,
#   'record_len': 10000,
#   'num_artifact': 1},
#  10: {'portal_id': 'ICUDataRedux_0069',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'Age': 41,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 11,
#   'mean_sz_len': 12.909,
#   'record_len': 2955,
#   'num_artifact': 0},
#  13: {'portal_id': 'ICUDataRedux_0072',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 33,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 12,
#   'mean_sz_len': 21.583,
#   'record_len': 5000,
#   'num_artifact': 1},
#  14: {'portal_id': 'ICUDataRedux_0073',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 88,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 4,
#   'mean_sz_len': 68.0,
#   'record_len': 20000,
#   'num_artifact': 204},
#  15: {'portal_id': 'ICUDataRedux_0074',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 63,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 11,
#   'mean_sz_len': 130.55,
#   'record_len': 10000,
#   'num_artifact': 0},
#  18: {'portal_id': 'ICUDataRedux_0054',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 81,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 5,
#   'mean_sz_len': 104.6,
#   'record_len': 16000,
#   'num_artifact': 357},
#  22: {'portal_id': 'ICUDataRedux_0078',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'Age': 72,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 2,
#   'mean_sz_len': 1260.5,
#   'record_len': 10000,
#   'num_artifact': 0},
#  23: {'portal_id': 'ICUDataRedux_0082',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 54,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 10,
#   'mean_sz_len': 134.7,
#   'record_len': 2800,
#   'num_artifact': 1},
#  24: {'portal_id': 'ICUDataRedux_0083',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'Age': 81,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 2,
#   'mean_sz_len': 42.0,
#   'record_len': 10000,
#   'num_artifact': 145},
#  25: {'portal_id': 'ICUDataRedux_0084',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 57,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 2,
#   'mean_sz_len': 147.0,
#   'record_len': 5000,
#   'num_artifact': 0},
#  26: {'portal_id': 'ICUDataRedux_0085',
#   'sz_presence': 1,
#   'diagnosis': 'Sepsis',
#   'Age': 52,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 22,
#   'mean_sz_len': 266.0,
#   'record_len': 15085,
#   'num_artifact': 0},
#  27: {'portal_id': 'ICUDataRedux_0086',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 28,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 16,
#   'mean_sz_len': 67.125,
#   'record_len': 9570,
#   'num_artifact': 16},
#  28: {'portal_id': 'ICUDataRedux_0087',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'Age': 52,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 5,
#   'mean_sz_len': 95.6,
#   'record_len': 10000,
#   'num_artifact': 0},
#  30: {'portal_id': 'ICUDataRedux_0089',
#   'sz_presence': 1,
#   'diagnosis': 'Sepsis',
#   'Age': 57,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 5,
#   'mean_sz_len': 265.6,
#   'record_len': 8000,
#   'num_artifact': 32},
#  31: {'portal_id': 'ICUDataRedux_0090',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 53,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 18,
#   'mean_sz_len': 94.222,
#   'record_len': 5000,
#   'num_artifact': 0},
#  32: {'portal_id': 'ICUDataRedux_0091',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'Age': 49,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 3,
#   'mean_sz_len': 315.33,
#   'record_len': 2000,
#   'num_artifact': 0},
#  33: {'portal_id': 'CNT684',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 31,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  34: {'portal_id': 'CNT685',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 22,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  35: {'portal_id': 'CNT686',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 21,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  36: {'portal_id': 'CNT687',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 25,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  37: {'portal_id': 'CNT688',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 74,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  38: {'portal_id': 'CNT689',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 71,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 1726},
#  39: {'portal_id': 'CNT690',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 69,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  40: {'portal_id': 'CNT691',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 84,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  41: {'portal_id': 'CNT692',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 24,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 17},
#  42: {'portal_id': 'CNT694',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 64,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  43: {'portal_id': 'CNT695',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 61,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  44: {'portal_id': 'CNT698',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 60,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 31},
#  45: {'portal_id': 'CNT700',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 64,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 198},
#  46: {'portal_id': 'CNT701',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 65,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  47: {'portal_id': 'CNT702',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 67,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 9},
#  48: {'portal_id': 'CNT705',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 60,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  49: {'portal_id': 'CNT706',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 67,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 17},
#  50: {'portal_id': 'CNT708',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 63,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 335},
#  51: {'portal_id': 'CNT710',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 45,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  52: {'portal_id': 'CNT711',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'Age': 53,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  53: {'portal_id': 'CNT713',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 75,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  54: {'portal_id': 'CNT715',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 55,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 7},
#  57: {'portal_id': 'CNT720',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 22,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 4},
#  59: {'portal_id': 'CNT723',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 22,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  60: {'portal_id': 'CNT724',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 86,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  61: {'portal_id': 'CNT725',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'Age': 67,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  62: {'portal_id': 'CNT726',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 19,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 111},
#  63: {'portal_id': 'CNT729',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 61,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  64: {'portal_id': 'CNT730',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 45,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  65: {'portal_id': 'CNT731',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 75,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  66: {'portal_id': 'CNT732',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 72,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  67: {'portal_id': 'CNT733',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 53,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 2},
#  68: {'portal_id': 'CNT734',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 52,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  69: {'portal_id': 'CNT737',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 68,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 1},
#  70: {'portal_id': 'CNT740',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 38,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  71: {'portal_id': 'CNT741',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 60,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 14},
#  72: {'portal_id': 'CNT742',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 54,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  73: {'portal_id': 'CNT743',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'Age': 64,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  74: {'portal_id': 'CNT748',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 44,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  75: {'portal_id': 'CNT750',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 53,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  76: {'portal_id': 'CNT751',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 62,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  77: {'portal_id': 'CNT757',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 74,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 3},
#  78: {'portal_id': 'CNT758',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 20,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 157},
#  79: {'portal_id': 'CNT765',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 81,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  80: {'portal_id': 'CNT773',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 81,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  81: {'portal_id': 'CNT774',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 44,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 1},
#  82: {'portal_id': 'CNT775',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'Age': 67,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  83: {'portal_id': 'CNT776',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'Age': 60,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  84: {'portal_id': 'CNT778',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 66,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  85: {'portal_id': 'CNT782',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 47,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  92: {'portal_id': 'ICUDataRedux_0003',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'Age': 71,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 1,
#   'mean_sz_len': 96.0,
#   'record_len': 5000,
#   'num_artifact': 0},
#  93: {'portal_id': 'ICUDataRedux_0004',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'Age': 63,
#   'Sex': 'M',
#   'Test_set': 0,
#   'sz_num': 1,
#   'mean_sz_len': 11.0,
#   'record_len': 10000,
#   'num_artifact': 0},
#  94: {'portal_id': 'ICUDataRedux_0006',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'Age': 76,
#   'Sex': 'F',
#   'Test_set': 0,
#   'sz_num': 1,
#   'mean_sz_len': 582.0,
#   'record_len': 5000,
#   'num_artifact': 0},
#  113: {'portal_id': 'CNT929',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 58,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 1,
#   'mean_sz_len': 132.0,
#   'record_len': 20000,
#   'num_artifact': 42},
#  116: {'portal_id': 'ICUDataRedux_0027',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'Age': 74,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 1,
#   'mean_sz_len': 909.0,
#   'record_len': 10000,
#   'num_artifact': 0},
#  117: {'portal_id': 'ICUDataRedux_0028',
#   'sz_presence': 1,
#   'diagnosis': 'AMS ',
#   'Age': 68,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 3,
#   'mean_sz_len': 310.0,
#   'record_len': 10000,
#   'num_artifact': 0},
#  118: {'portal_id': 'ICUDataRedux_0033',
#   'sz_presence': 1,
#   'diagnosis': 'AMS ',
#   'Age': 79,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 6,
#   'mean_sz_len': 62.5,
#   'record_len': 5000,
#   'num_artifact': 0},
#  119: {'portal_id': 'ICUDataRedux_0036',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 86,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 1,
#   'mean_sz_len': 193.0,
#   'record_len': 2000,
#   'num_artifact': 0},
#  120: {'portal_id': 'ICUDataRedux_0040',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 74,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 1,
#   'mean_sz_len': 5000.0,
#   'record_len': 5000,
#   'num_artifact': 0},
#  121: {'portal_id': 'ICUDataRedux_0042',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'Age': 19,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 2,
#   'mean_sz_len': 52.5,
#   'record_len': 13000,
#   'num_artifact': 0},
#  122: {'portal_id': 'ICUDataRedux_0045',
#   'sz_presence': 1,
#   'diagnosis': 'SZ ',
#   'Age': 60,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 1,
#   'mean_sz_len': 95.0,
#   'record_len': 7000,
#   'num_artifact': 0},
#  123: {'portal_id': 'ICUDataRedux_0049',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'Age': 16,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 9,
#   'mean_sz_len': 38.889,
#   'record_len': 10000,
#   'num_artifact': 0},
#  124: {'portal_id': 'ICUDataRedux_0050',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'Age': 21,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 2,
#   'mean_sz_len': 63.0,
#   'record_len': 5000,
#   'num_artifact': 0},
#  125: {'portal_id': 'ICUDataRedux_0023',
#   'sz_presence': 2,
#   'diagnosis': 'Sepsis',
#   'Age': 51,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 163},
#  126: {'portal_id': 'ICUDataRedux_0026',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 74,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  127: {'portal_id': 'ICUDataRedux_0029',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 73,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 8},
#  128: {'portal_id': 'ICUDataRedux_0030',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'Age': 43,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 11},
#  129: {'portal_id': 'ICUDataRedux_0034',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 49,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 40},
#  130: {'portal_id': 'ICUDataRedux_0035',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 30,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  131: {'portal_id': 'ICUDataRedux_0043',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'Age': 38,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  132: {'portal_id': 'ICUDataRedux_0044',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'Age': 64,
#   'Sex': 'M',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0},
#  133: {'portal_id': 'ICUDataRedux_0047',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'Age': 58,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 46},
#  134: {'portal_id': 'ICUDataRedux_0048',
#   'sz_presence': 2,
#   'diagnosis': 'Sepsis',
#   'Age': 60,
#   'Sex': 'F',
#   'Test_set': 1,
#   'sz_num': 0,
#   'mean_sz_len': nan,
#   'record_len': 10000,
#   'num_artifact': 0}}

# %%
for anum,data in annotations.items():
    num = int(anum)
    if num in ptdatadict:
        #print(f"{type(data)}")
        #print(f"{data}")
        data['portal_id'] = ptdatadict[num]['portal_id']
        data['sz_presence'] = ptdatadict[num]['sz_presence']
        data['diagnosis'] = ptdatadict[num]['diagnosis']
        if ptdatadict[num]['sz_presence']:
            data['pt_type'] = 1
        else:
            data['pt_type'] = 2
        del data['type']

# %%
yaml.safe_dump(annotations, open('patient_annotations.yaml','w+'))
json.dump(annotations, open('patient_annotations.json','w+'), indent=2)

# %%
annotations
# Out:
# {1: {'data_start': 24000,
#   'data_stop': 54000,
#   'file_num': 1,
#   'ii_start': [24000, 24846, 51868],
#   'ii_stop': [24742, 51771, 54000],
#   'patient': 'ICUDataRedux_0060',
#   'sz_start': [24742, 51771],
#   'sz_stop': [24846, 51868],
#   'portal_id': 'ICUDataRedux_0060',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  2: {'data_start': 1968,
#   'data_stop': 33825,
#   'file_num': 2,
#   'ii_start': [2055,
#    6120,
#    6288,
#    8491,
#    9455,
#    10471,
#    10690,
#    13432,
#    13612,
#    13853,
#    14581,
#    14802,
#    15572,
#    15771,
#    15809,
#    16052,
#    18846,
#    19029,
#    19278,
#    21721,
#    21899,
#    22098,
#    23607,
#    23763,
#    24958,
#    25163,
#    25214,
#    25282,
#    26738,
#    26915,
#    27081,
#    27265,
#    28477,
#    28638,
#    28760,
#    28930,
#    30003,
#    30171,
#    30237,
#    30395,
#    31266,
#    31423,
#    31529,
#    31671,
#    32483,
#    32659,
#    32741,
#    33720],
#   'ii_stop': [6057,
#    6208,
#    8413,
#    9376,
#    10373,
#    10569,
#    13350,
#    13504,
#    13721,
#    14476,
#    14619,
#    15474,
#    15647,
#    15776,
#    15866,
#    18771,
#    18916,
#    19109,
#    21640,
#    21796,
#    21967,
#    23508,
#    23642,
#    24787,
#    24996,
#    25168,
#    25217,
#    26658,
#    26799,
#    26945,
#    27136,
#    28388,
#    28526,
#    28655,
#    28790,
#    29916,
#    30033,
#    30175,
#    30241,
#    31161,
#    31271,
#    31428,
#    31535,
#    32373,
#    32486,
#    32666,
#    33599,
#    33745],
#   'patient': 'ICUDataRedux_0061',
#   'sz_start': [1968,
#    6057,
#    6208,
#    8413,
#    9376,
#    10373,
#    10569,
#    13350,
#    13504,
#    13721,
#    14476,
#    14619,
#    15474,
#    15647,
#    15776,
#    15866,
#    18771,
#    18916,
#    19109,
#    21640,
#    21796,
#    21967,
#    23508,
#    23642,
#    24787,
#    24996,
#    25168,
#    25217,
#    26658,
#    26799,
#    26945,
#    27136,
#    28388,
#    28526,
#    28655,
#    28790,
#    29916,
#    30033,
#    30175,
#    30241,
#    31161,
#    31271,
#    31428,
#    31535,
#    32373,
#    32486,
#    32666,
#    33599,
#    33745],
#   'sz_stop': [2055,
#    6120,
#    6288,
#    8491,
#    9455,
#    10471,
#    10690,
#    13432,
#    13612,
#    13853,
#    14581,
#    14802,
#    15572,
#    15771,
#    15809,
#    16052,
#    18846,
#    19029,
#    19278,
#    21721,
#    21899,
#    22098,
#    23607,
#    23763,
#    24958,
#    25163,
#    25214,
#    25282,
#    26738,
#    26915,
#    27081,
#    27265,
#    28477,
#    28638,
#    28760,
#    28930,
#    30003,
#    30171,
#    30237,
#    30395,
#    31266,
#    31423,
#    31529,
#    31671,
#    32483,
#    32659,
#    32741,
#    33720,
#    33825],
#   'portal_id': 'ICUDataRedux_0061',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  3: {'data_start': 500,
#   'data_stop': 24000,
#   'file_num': 3,
#   'ii_start': [500,
#    878,
#    1799,
#    2228,
#    8771,
#    9146,
#    10238,
#    11020,
#    11376,
#    16153,
#    16238,
#    16454,
#    16607,
#    16715,
#    16852,
#    16947,
#    18018,
#    18340,
#    18501,
#    20429,
#    21125,
#    21415,
#    21655],
#   'ii_stop': [860,
#    1784,
#    2210,
#    8757,
#    9127,
#    10234,
#    11000,
#    11361,
#    16114,
#    16210,
#    16441,
#    16582,
#    16695,
#    16830,
#    16928,
#    17996,
#    18318,
#    18469,
#    20406,
#    21098,
#    21375,
#    21623,
#    24000],
#   'patient': 'ICUDataRedux_0062',
#   'sz_start': [860,
#    1784,
#    2210,
#    8757,
#    9127,
#    10234,
#    11000,
#    11361,
#    16114,
#    16210,
#    16441,
#    16582,
#    16695,
#    16830,
#    16928,
#    17996,
#    18318,
#    18469,
#    20406,
#    21098,
#    21375,
#    21623],
#   'sz_stop': [878,
#    1799,
#    2228,
#    8771,
#    9146,
#    10238,
#    11020,
#    11376,
#    16153,
#    16238,
#    16454,
#    16607,
#    16715,
#    16852,
#    16947,
#    18018,
#    18340,
#    18501,
#    20429,
#    21125,
#    21415,
#    21655],
#   'portal_id': 'ICUDataRedux_0062',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  4: {'data_start': 1500,
#   'data_stop': 31672,
#   'file_num': 4,
#   'ii_start': [1500, 1932, 4206, 4753, 8245],
#   'ii_stop': [1912, 4178, 4740, 8226, 11500],
#   'patient': 'ICUDataRedux_0063',
#   'sz_start': [1912, 4178, 4740, 8226, 31648],
#   'sz_stop': [1932, 4206, 4753, 8245, 31672],
#   'portal_id': 'ICUDataRedux_0063',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  5: {'data_start': 43,
#   'data_stop': 15041,
#   'file_num': 5,
#   'ii_start': [105,
#    363,
#    634,
#    912,
#    1220,
#    1526,
#    1864,
#    2250,
#    2694,
#    3316,
#    3780,
#    3868,
#    4052,
#    4441,
#    4660,
#    5679,
#    6179,
#    6420,
#    6716,
#    7009,
#    7346,
#    7724,
#    8758,
#    9397,
#    10318,
#    10545,
#    10884,
#    11244,
#    11735,
#    12163,
#    12480,
#    12822,
#    12890,
#    13165,
#    13542,
#    13864,
#    14202,
#    14623],
#   'ii_stop': [295,
#    567,
#    839,
#    1139,
#    1443,
#    1778,
#    2161,
#    2605,
#    3194,
#    3648,
#    3804,
#    3977,
#    4367,
#    4586,
#    5583,
#    6096,
#    6354,
#    6637,
#    6935,
#    7265,
#    7634,
#    8637,
#    9296,
#    10222,
#    10478,
#    10842,
#    11181,
#    11680,
#    12114,
#    12428,
#    12768,
#    12862,
#    13110,
#    13483,
#    13803,
#    14146,
#    14560,
#    14978],
#   'patient': 'ICUDataRedux_0064',
#   'sz_start': [43,
#    295,
#    567,
#    839,
#    1139,
#    1443,
#    1778,
#    2161,
#    2605,
#    3194,
#    3648,
#    3804,
#    3977,
#    4367,
#    4586,
#    5583,
#    6096,
#    6354,
#    6637,
#    6935,
#    7265,
#    7634,
#    8637,
#    9296,
#    10222,
#    10478,
#    10842,
#    11181,
#    11680,
#    12114,
#    12428,
#    12768,
#    12862,
#    13110,
#    13483,
#    13803,
#    14146,
#    14560,
#    14978],
#   'sz_stop': [105,
#    363,
#    634,
#    912,
#    1220,
#    1526,
#    1864,
#    2250,
#    2694,
#    3316,
#    3780,
#    3868,
#    4052,
#    4441,
#    4660,
#    5679,
#    6179,
#    6420,
#    6716,
#    7009,
#    7346,
#    7724,
#    8758,
#    9397,
#    10318,
#    10545,
#    10884,
#    11244,
#    11735,
#    12163,
#    12480,
#    12822,
#    12890,
#    13165,
#    13542,
#    13864,
#    14202,
#    14623,
#    15041],
#   'portal_id': 'ICUDataRedux_0064',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  6: {'data_start': 13000,
#   'data_stop': 20000,
#   'file_num': 6,
#   'ii_start': [13000, 13827, 15581, 18368, 19763],
#   'ii_stop': [13709, 15433, 18216, 19625, 20000],
#   'patient': 'ICUDataRedux_0065',
#   'sz_start': [13709, 15433, 18216, 19625],
#   'sz_stop': [13827, 15581, 18368, 19763],
#   'portal_id': 'ICUDataRedux_0065',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  7: {'data_start': 1000,
#   'data_stop': 38000,
#   'file_num': 7,
#   'ii_start': [1000, 1948, 5178, 18542, 30618, 37424],
#   'ii_stop': [1671, 5067, 18168, 30430, 37253, 38000],
#   'patient': 'ICUDataRedux_0066',
#   'sz_start': [1671, 5067, 18168, 30430, 37253],
#   'sz_stop': [1948, 5178, 18542, 30618, 37424],
#   'portal_id': 'ICUDataRedux_0066',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  8: {'data_start': 45066,
#   'data_stop': 78041,
#   'file_num': 8,
#   'ii_start': [45227, 47809, 77890],
#   'ii_stop': [47603, 77814, 77928],
#   'patient': 'ICUDataRedux_0067',
#   'sz_start': [45066, 47603, 77814, 77928],
#   'sz_stop': [45227, 47809, 77890, 78041],
#   'portal_id': 'ICUDataRedux_0067',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  9: {'data_start': 2000,
#   'data_stop': 12000,
#   'file_num': 9,
#   'ii_start': [2000, 3444, 3592, 3897, 5005],
#   'ii_stop': [3374, 3577, 3879, 4989, 12000],
#   'patient': 'ICUDataRedux_0068',
#   'sz_start': [3374, 3577, 3879, 4989],
#   'sz_stop': [3444, 3592, 3897, 5005],
#   'portal_id': 'ICUDataRedux_0068',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  10: {'data_start': 3200,
#   'data_stop': 6157,
#   'file_num': 10,
#   'ii_start': [3200,
#    5139,
#    5201,
#    5276,
#    5338,
#    5436,
#    5609,
#    5730,
#    5763,
#    5862,
#    5949],
#   'ii_stop': [5128,
#    5187,
#    5263,
#    5322,
#    5420,
#    5593,
#    5720,
#    5754,
#    5846,
#    5940,
#    6145],
#   'patient': 'ICUDataRedux_0069',
#   'sz_start': [5128,
#    5187,
#    5263,
#    5322,
#    5420,
#    5593,
#    5720,
#    5754,
#    5846,
#    5940,
#    6145],
#   'sz_stop': [5139,
#    5201,
#    5276,
#    5338,
#    5436,
#    5609,
#    5730,
#    5763,
#    5862,
#    5949,
#    6157],
#   'portal_id': 'ICUDataRedux_0069',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  13: {'data_start': 100,
#   'data_stop': 5100,
#   'file_num': 13,
#   'ii_start': [100,
#    990,
#    2545,
#    2587,
#    2733,
#    3255,
#    3307,
#    3367,
#    3435,
#    3578,
#    3592,
#    3659,
#    3740],
#   'ii_stop': [956,
#    2509,
#    2573,
#    2721,
#    3235,
#    3298,
#    3315,
#    3417,
#    3568,
#    3580,
#    3635,
#    3722,
#    5100],
#   'patient': 'ICUDataRedux_0072',
#   'sz_start': [956,
#    2509,
#    2573,
#    2721,
#    3235,
#    3298,
#    3315,
#    3417,
#    3568,
#    3580,
#    3635,
#    3722],
#   'sz_stop': [990,
#    2545,
#    2587,
#    2733,
#    3255,
#    3307,
#    3367,
#    3435,
#    3578,
#    3592,
#    3659,
#    3740],
#   'portal_id': 'ICUDataRedux_0072',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  14: {'data_start': 10100,
#   'data_stop': 30100,
#   'file_num': 14,
#   'ii_start': [10100, 10345, 21237, 25491, 25655],
#   'ii_stop': [10271, 21145, 25413, 25627, 30100],
#   'patient': 'ICUDataRedux_0073',
#   'sz_start': [10271, 21145, 25413, 25627],
#   'sz_stop': [10345, 21237, 25491, 25655],
#   'portal_id': 'ICUDataRedux_0073',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  15: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 15,
#   'ii_start': [100,
#    267,
#    367,
#    1070,
#    1441,
#    2333,
#    2527,
#    2700,
#    2790,
#    3253,
#    4671,
#    5164],
#   'ii_stop': [114,
#    307,
#    981,
#    1322,
#    2214,
#    2393,
#    2551,
#    2730,
#    3148,
#    4462,
#    4925,
#    10100],
#   'patient': 'ICUDataRedux_0074',
#   'sz_start': [114, 307, 981, 1322, 2214, 2393, 2551, 2730, 3148, 4462, 4925],
#   'sz_stop': [267, 367, 1070, 1441, 2333, 2527, 2700, 2790, 3253, 4671, 5164],
#   'portal_id': 'ICUDataRedux_0074',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  18: {'data_start': 100,
#   'data_stop': 16100,
#   'file_num': 18,
#   'ii_start': [100, 4530, 5597, 7537, 13498, 15409],
#   'ii_stop': [4355, 5463, 7474, 13469, 15287, 16100],
#   'patient': 'ICUDataRedux_0054',
#   'sz_start': [4355, 5463, 7474, 13469, 15287],
#   'sz_stop': [4530, 5597, 7537, 13498, 15409],
#   'portal_id': 'ICUDataRedux_0054',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  22: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 22,
#   'ii_start': [1000, 5893, 8365],
#   'ii_stop': [5607, 6130, 11000],
#   'patient': 'ICUDataRedux_0078',
#   'sz_start': [5607, 6130],
#   'sz_stop': [5893, 8365],
#   'portal_id': 'ICUDataRedux_0078',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  23: {'data_start': 1658,
#   'data_stop': 4458,
#   'file_num': 23,
#   'ii_start': [1763, 2127, 2327, 2532, 2820, 3054, 3170, 3308, 3728],
#   'ii_stop': [1942, 2178, 2340, 2684, 2842, 3139, 3184, 3617, 4356],
#   'patient': 'ICUDataRedux_0082',
#   'sz_start': [1658, 1942, 2178, 2340, 2684, 2842, 3139, 3184, 3617, 4356],
#   'sz_stop': [1763, 2127, 2327, 2532, 2820, 3054, 3170, 3308, 3728, 4458],
#   'portal_id': 'ICUDataRedux_0082',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  24: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 24,
#   'ii_start': [100, 2475, 4723],
#   'ii_stop': [2422, 4692, 10100],
#   'patient': 'ICUDataRedux_0083',
#   'sz_start': [2422, 4692],
#   'sz_stop': [2475, 4723],
#   'portal_id': 'ICUDataRedux_0083',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  25: {'data_start': 1000,
#   'data_stop': 6000,
#   'file_num': 25,
#   'ii_start': [1000, 1193, 2330],
#   'ii_stop': [1036, 2193, 6000],
#   'patient': 'ICUDataRedux_0084',
#   'sz_start': [1036, 2193],
#   'sz_stop': [1193, 2330],
#   'portal_id': 'ICUDataRedux_0084',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  26: {'data_start': 79,
#   'data_stop': 15164,
#   'file_num': 26,
#   'ii_start': [243,
#    720,
#    1092,
#    1285,
#    1911,
#    2625,
#    3156,
#    3767,
#    4318,
#    4883,
#    5494,
#    5970,
#    6596,
#    7236,
#    7619,
#    7857,
#    8557,
#    9357,
#    10623,
#    12409,
#    13601],
#   'ii_stop': [422,
#    973,
#    1092,
#    1643,
#    2209,
#    2665,
#    3484,
#    3945,
#    4630,
#    5181,
#    5672,
#    6372,
#    7072,
#    7545,
#    7693,
#    8334,
#    9089,
#    10280,
#    12037,
#    13467,
#    14747],
#   'patient': 'ICUDataRedux_0085',
#   'sz_start': [79,
#    422,
#    973,
#    1092,
#    1643,
#    2209,
#    2665,
#    3484,
#    3945,
#    4630,
#    5181,
#    5672,
#    6372,
#    7072,
#    7545,
#    7693,
#    8334,
#    9089,
#    10280,
#    12037,
#    13467,
#    14747],
#   'sz_stop': [243,
#    720,
#    1092,
#    1285,
#    1911,
#    2625,
#    3156,
#    3767,
#    4318,
#    4883,
#    5494,
#    5970,
#    6596,
#    7236,
#    7619,
#    7857,
#    8557,
#    9357,
#    10623,
#    12409,
#    13601,
#    15164],
#   'portal_id': 'ICUDataRedux_0085',
#   'sz_presence': 1,
#   'diagnosis': 'Sepsis',
#   'pt_type': 1},
#  27: {'data_start': 1941,
#   'data_stop': 11515,
#   'file_num': 27,
#   'ii_start': [1997,
#    3205,
#    3524,
#    4150,
#    4959,
#    5192,
#    7021,
#    7272,
#    8508,
#    9285,
#    9697,
#    10432,
#    10672,
#    10885,
#    11336],
#   'ii_stop': [3123,
#    3457,
#    4078,
#    4868,
#    5096,
#    6923,
#    7176,
#    8444,
#    9218,
#    9652,
#    10386,
#    10617,
#    10835,
#    11300,
#    11462],
#   'patient': 'ICUDataRedux_0086',
#   'sz_start': [1941,
#    3123,
#    3457,
#    4078,
#    4868,
#    5096,
#    6923,
#    7176,
#    8444,
#    9218,
#    9652,
#    10386,
#    10617,
#    10835,
#    11300,
#    11462],
#   'sz_stop': [1997,
#    3205,
#    3524,
#    4150,
#    4959,
#    5192,
#    7021,
#    7272,
#    8508,
#    9285,
#    9697,
#    10432,
#    10672,
#    10885,
#    11336,
#    11515],
#   'portal_id': 'ICUDataRedux_0086',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  28: {'data_start': 2000,
#   'data_stop': 12000,
#   'file_num': 28,
#   'ii_start': [2000, 2275, 2599, 3547, 4320, 8799],
#   'ii_stop': [2230, 2494, 3443, 4230, 8665, 12000],
#   'patient': 'ICUDataRedux_0087',
#   'sz_start': [2230, 2494, 3443, 4230, 8665],
#   'sz_stop': [2275, 2599, 3547, 4320, 8799],
#   'portal_id': 'ICUDataRedux_0087',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  30: {'data_start': 30,
#   'data_stop': 8030,
#   'file_num': 30,
#   'ii_start': [30, 434, 1853, 3293, 5199, 7233],
#   'ii_stop': [48, 1577, 3001, 4939, 7119, 8030],
#   'patient': 'ICUDataRedux_0089',
#   'sz_start': [48, 1577, 3001, 4939, 7119],
#   'sz_stop': [434, 1853, 3293, 5199, 7233],
#   'portal_id': 'ICUDataRedux_0089',
#   'sz_presence': 1,
#   'diagnosis': 'Sepsis',
#   'pt_type': 1},
#  31: {'data_start': 3000,
#   'data_stop': 8000,
#   'file_num': 31,
#   'ii_start': [3000,
#    3250,
#    3309,
#    3473,
#    3622,
#    3746,
#    3871,
#    3971,
#    4833,
#    5044,
#    5091,
#    5345,
#    5509,
#    5625,
#    5729,
#    5911,
#    6556,
#    6696,
#    6776],
#   'ii_stop': [3205,
#    3279,
#    3369,
#    3532,
#    3641,
#    3811,
#    3925,
#    4766,
#    4952,
#    5057,
#    5226,
#    5450,
#    5529,
#    5670,
#    5836,
#    6083,
#    6607,
#    6723,
#    8000],
#   'patient': 'ICUDataRedux_0090',
#   'sz_start': [3205,
#    3279,
#    3369,
#    3532,
#    3641,
#    3811,
#    3925,
#    4766,
#    4952,
#    5057,
#    5226,
#    5450,
#    5529,
#    5670,
#    5836,
#    6083,
#    6607,
#    6723],
#   'sz_stop': [3250,
#    3309,
#    3473,
#    3622,
#    3746,
#    3871,
#    3971,
#    4833,
#    5044,
#    5091,
#    5345,
#    5509,
#    5625,
#    5729,
#    5911,
#    6556,
#    6696,
#    6776],
#   'portal_id': 'ICUDataRedux_0090',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  32: {'data_start': 400,
#   'data_stop': 2400,
#   'file_num': 32,
#   'ii_start': [400, 747, 1312, 2160],
#   'ii_stop': [468, 980, 1825, 2400],
#   'patient': 'ICUDataRedux_0091',
#   'sz_start': [468, 980, 1825],
#   'sz_stop': [747, 1312, 2160],
#   'portal_id': 'ICUDataRedux_0091',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  33: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 33,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT684',
#   'portal_id': 'CNT684',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  34: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 34,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT685',
#   'portal_id': 'CNT685',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  35: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 35,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT686',
#   'portal_id': 'CNT686',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  36: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 36,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT687',
#   'portal_id': 'CNT687',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  37: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 37,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT688',
#   'portal_id': 'CNT688',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  38: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 38,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT689',
#   'portal_id': 'CNT689',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  39: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 39,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT690',
#   'portal_id': 'CNT690',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  40: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 40,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT691',
#   'portal_id': 'CNT691',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  41: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 41,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT692',
#   'portal_id': 'CNT692',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  42: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 42,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT694',
#   'portal_id': 'CNT694',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  43: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 43,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT695',
#   'portal_id': 'CNT695',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  44: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 44,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT698',
#   'portal_id': 'CNT698',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  45: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 45,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT700',
#   'portal_id': 'CNT700',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  46: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 46,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT701',
#   'portal_id': 'CNT701',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  47: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 47,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT702',
#   'portal_id': 'CNT702',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  48: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 48,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT705',
#   'portal_id': 'CNT705',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  49: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 49,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT706',
#   'portal_id': 'CNT706',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  50: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 50,
#   'ii_start': [100],
#   'ii_stop': [10100],
#   'patient': 'CNT708',
#   'portal_id': 'CNT708',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  51: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 51,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT710',
#   'portal_id': 'CNT710',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  52: {'data_start': 5000,
#   'data_stop': 15000,
#   'file_num': 52,
#   'ii_start': [5000],
#   'ii_stop': [15000],
#   'patient': 'CNT711',
#   'portal_id': 'CNT711',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  53: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 53,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT713',
#   'portal_id': 'CNT713',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  54: {'data_start': 5000,
#   'data_stop': 15000,
#   'file_num': 54,
#   'ii_start': [5000],
#   'ii_stop': [15000],
#   'patient': 'CNT715',
#   'portal_id': 'CNT715',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  57: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 57,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT720',
#   'portal_id': 'CNT720',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  59: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 59,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT723',
#   'portal_id': 'CNT723',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  60: {'data_start': 2000,
#   'data_stop': 12000,
#   'file_num': 60,
#   'ii_start': [2000],
#   'ii_stop': [12000],
#   'patient': 'CNT724',
#   'portal_id': 'CNT724',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  61: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 61,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT725',
#   'portal_id': 'CNT725',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  62: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 62,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT726',
#   'portal_id': 'CNT726',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  63: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 63,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT729',
#   'portal_id': 'CNT729',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  64: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 64,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT730',
#   'portal_id': 'CNT730',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  65: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 65,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT731',
#   'portal_id': 'CNT731',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  66: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 66,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT732',
#   'portal_id': 'CNT732',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  67: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 67,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT733',
#   'portal_id': 'CNT733',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  68: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 68,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT734',
#   'portal_id': 'CNT734',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  69: {'data_start': 2000,
#   'data_stop': 12000,
#   'file_num': 69,
#   'ii_start': [2000],
#   'ii_stop': [12000],
#   'patient': 'CNT737',
#   'portal_id': 'CNT737',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  70: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 70,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT740',
#   'portal_id': 'CNT740',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  71: {'data_start': 40000,
#   'data_stop': 50000,
#   'file_num': 71,
#   'ii_start': [40000],
#   'ii_stop': [50000],
#   'patient': 'CNT741',
#   'portal_id': 'CNT741',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  72: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 72,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT742',
#   'portal_id': 'CNT742',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  73: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 73,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT743',
#   'portal_id': 'CNT743',
#   'sz_presence': 2,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  74: {'data_start': 8000,
#   'data_stop': 18000,
#   'file_num': 74,
#   'ii_start': [8000],
#   'ii_stop': [18000],
#   'patient': 'CNT748',
#   'portal_id': 'CNT748',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  75: {'data_start': 3000,
#   'data_stop': 13000,
#   'file_num': 75,
#   'ii_start': [3000],
#   'ii_stop': [13000],
#   'patient': 'CNT750',
#   'portal_id': 'CNT750',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  76: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 76,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT751',
#   'portal_id': 'CNT751',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  77: {'data_start': 9000,
#   'data_stop': 19000,
#   'file_num': 77,
#   'ii_start': [9000],
#   'ii_stop': [19000],
#   'patient': 'CNT757',
#   'portal_id': 'CNT757',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  78: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 78,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT758',
#   'portal_id': 'CNT758',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  79: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 79,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT765',
#   'portal_id': 'CNT765',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  80: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 80,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'CNT773',
#   'portal_id': 'CNT773',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  81: {'data_start': 35000,
#   'data_stop': 45000,
#   'file_num': 81,
#   'ii_start': [35000],
#   'ii_stop': [45000],
#   'patient': 'CNT774',
#   'portal_id': 'CNT774',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  82: {'data_start': 7000,
#   'data_stop': 17000,
#   'file_num': 82,
#   'ii_start': [7000],
#   'ii_stop': [17000],
#   'patient': 'CNT775',
#   'portal_id': 'CNT775',
#   'sz_presence': 2,
#   'diagnosis': 'Toxometabolic',
#   'pt_type': 1},
#  83: {'data_start': 2000,
#   'data_stop': 12000,
#   'file_num': 83,
#   'ii_start': [2000],
#   'ii_stop': [12000],
#   'patient': 'CNT776',
#   'portal_id': 'CNT776',
#   'sz_presence': 2,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  84: {'data_start': 13000,
#   'data_stop': 23000,
#   'file_num': 84,
#   'ii_start': [13000],
#   'ii_stop': [23000],
#   'patient': 'CNT778',
#   'portal_id': 'CNT778',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  85: {'data_start': 6000,
#   'data_stop': 16000,
#   'file_num': 85,
#   'ii_start': [6000],
#   'ii_stop': [16000],
#   'patient': 'CNT782',
#   'portal_id': 'CNT782',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  92: {'data_start': 25000,
#   'data_stop': 30000,
#   'file_num': 92,
#   'ii_start': [25000, 26019],
#   'ii_stop': [25923, 30000],
#   'patient': 'ICUDataRedux_0003',
#   'sz_start': [25923],
#   'sz_stop': [26019],
#   'portal_id': 'ICUDataRedux_0003',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  93: {'data_start': 20000,
#   'data_stop': 30000,
#   'file_num': 93,
#   'ii_start': [20000, 23136],
#   'ii_stop': [23125, 30000],
#   'patient': 'ICUDataRedux_0004',
#   'sz_start': [23125],
#   'sz_stop': [23136],
#   'portal_id': 'ICUDataRedux_0004',
#   'sz_presence': 1,
#   'diagnosis': 'Neoplasm',
#   'pt_type': 1},
#  94: {'data_start': 20600,
#   'data_stop': 25600,
#   'file_num': 94,
#   'ii_start': [20600, 25389],
#   'ii_stop': [24807, 25600],
#   'patient': 'ICUDataRedux_0006',
#   'sz_start': [24807],
#   'sz_stop': [25389],
#   'portal_id': 'ICUDataRedux_0006',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  113: {'data_start': 20000,
#   'data_stop': 40000,
#   'file_num': 113,
#   'ii_start': [20000, 33151],
#   'ii_stop': [33019, 40000],
#   'patient': 'CNT929',
#   'sz_start': [33019],
#   'sz_stop': [33151],
#   'portal_id': 'CNT929',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  116: {'data_start': 10000,
#   'data_stop': 20000,
#   'file_num': 116,
#   'ii_start': [10000, 15709],
#   'ii_stop': [14800, 20000],
#   'patient': 'ICUDataRedux_0027',
#   'sz_start': [14800],
#   'sz_stop': [15709],
#   'portal_id': 'ICUDataRedux_0027',
#   'sz_presence': 1,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  117: {'data_start': 71000,
#   'data_stop': 81000,
#   'file_num': 117,
#   'ii_start': [71000, 75805, 78447, 80508],
#   'ii_stop': [75383, 78293, 80154, 81000],
#   'patient': 'ICUDataRedux_0028',
#   'sz_start': [75383, 78293, 80154],
#   'sz_stop': [75805, 78447, 80508],
#   'portal_id': 'ICUDataRedux_0028',
#   'sz_presence': 1,
#   'diagnosis': 'AMS ',
#   'pt_type': 1},
#  118: {'data_start': 800,
#   'data_stop': 5800,
#   'file_num': 118,
#   'ii_start': [800, 834, 1187, 1447, 3158, 3719, 5716],
#   'ii_stop': [807, 1162, 1383, 3131, 3585, 5618, 5800],
#   'patient': 'ICUDataRedux_0033',
#   'sz_start': [807, 1162, 1383, 3131, 3585, 5618],
#   'sz_stop': [834, 1187, 1447, 3158, 3719, 5716],
#   'portal_id': 'ICUDataRedux_0033',
#   'sz_presence': 1,
#   'diagnosis': 'AMS ',
#   'pt_type': 1},
#  119: {'data_start': 200,
#   'data_stop': 2200,
#   'file_num': 119,
#   'ii_start': [200, 435],
#   'ii_stop': [242, 2200],
#   'patient': 'ICUDataRedux_0036',
#   'sz_start': [242],
#   'sz_stop': [435],
#   'portal_id': 'ICUDataRedux_0036',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  120: {'data_start': 2000,
#   'data_stop': 7000,
#   'file_num': 120,
#   'ii_start': [0, 0],
#   'ii_stop': [0, 0],
#   'patient': 'ICUDataRedux_0040',
#   'sz_start': [2000],
#   'sz_stop': [7000],
#   'portal_id': 'ICUDataRedux_0040',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  121: {'data_start': 3000,
#   'data_stop': 16000,
#   'file_num': 121,
#   'ii_start': [3000, 3331, 15128],
#   'ii_stop': [3251, 15103, 16000],
#   'patient': 'ICUDataRedux_0042',
#   'sz_start': [3251, 15103],
#   'sz_stop': [3331, 15128],
#   'portal_id': 'ICUDataRedux_0042',
#   'sz_presence': 1,
#   'diagnosis': 'Misc/UC',
#   'pt_type': 1},
#  122: {'data_start': 5000,
#   'data_stop': 12000,
#   'file_num': 122,
#   'ii_start': [5000, 9773],
#   'ii_stop': [9678, 12000],
#   'patient': 'ICUDataRedux_0045',
#   'sz_start': [9678],
#   'sz_stop': [9773],
#   'portal_id': 'ICUDataRedux_0045',
#   'sz_presence': 1,
#   'diagnosis': 'SZ ',
#   'pt_type': 1},
#  123: {'data_start': 100,
#   'data_stop': 10100,
#   'file_num': 123,
#   'ii_start': [100, 3583, 3660, 7164, 9501, 9574, 9625, 9761, 9854, 9976],
#   'ii_stop': [3501, 3607, 7119, 9485, 9560, 9595, 9732, 9821, 9928, 10100],
#   'patient': 'ICUDataRedux_0049',
#   'sz_start': [3501, 3607, 7119, 9485, 9560, 9595, 9732, 9821, 9928],
#   'sz_stop': [3583, 3660, 7164, 9501, 9574, 9625, 9761, 9854, 9976],
#   'portal_id': 'ICUDataRedux_0049',
#   'sz_presence': 1,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  124: {'data_start': 3000,
#   'data_stop': 8000,
#   'file_num': 124,
#   'ii_start': [3000, 3177, 5384],
#   'ii_stop': [3119, 5316, 8000],
#   'patient': 'ICUDataRedux_0050',
#   'sz_start': [3119, 5316],
#   'sz_stop': [3177, 5384],
#   'portal_id': 'ICUDataRedux_0050',
#   'sz_presence': 1,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  125: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 125,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0023',
#   'portal_id': 'ICUDataRedux_0023',
#   'sz_presence': 2,
#   'diagnosis': 'Sepsis',
#   'pt_type': 1},
#  126: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 126,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0026',
#   'portal_id': 'ICUDataRedux_0026',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  127: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 127,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0029',
#   'portal_id': 'ICUDataRedux_0029',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  128: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 128,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0030',
#   'portal_id': 'ICUDataRedux_0030',
#   'sz_presence': 2,
#   'diagnosis': 'ICH',
#   'pt_type': 1},
#  129: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 129,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0034',
#   'portal_id': 'ICUDataRedux_0034',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  130: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 130,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0035',
#   'portal_id': 'ICUDataRedux_0035',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  131: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 131,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0043',
#   'portal_id': 'ICUDataRedux_0043',
#   'sz_presence': 2,
#   'diagnosis': 'SZ',
#   'pt_type': 1},
#  132: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 132,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0044',
#   'portal_id': 'ICUDataRedux_0044',
#   'sz_presence': 2,
#   'diagnosis': 'Anoxic',
#   'pt_type': 1},
#  133: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 133,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0047',
#   'portal_id': 'ICUDataRedux_0047',
#   'sz_presence': 2,
#   'diagnosis': 'AMS',
#   'pt_type': 1},
#  134: {'data_start': 1000,
#   'data_stop': 11000,
#   'file_num': 134,
#   'ii_start': [1000],
#   'ii_stop': [11000],
#   'patient': 'ICUDataRedux_0048',
#   'portal_id': 'ICUDataRedux_0048',
#   'sz_presence': 2,
#   'diagnosis': 'Sepsis',
#   'pt_type': 1}}
